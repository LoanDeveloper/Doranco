# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Dans chacun des exercices suivants, une cellule de code prépare des données synthétiques, il faut lancer cette cellule avant de faire l'exercice.

# %% [markdown]
# ### Exercice 1 : Le Graphique Financier (Dual Axis & Fill Between)
# Le concept : En finance ou en science, on doit souvent superposer deux données qui n'ont pas la même unité (ex: Prix en € et Volume en nombre d'actions, ou Température et Précipitations).
#
# Scénario : Visualisez le cours d'une action sur 100 jours.
#
# Axe Y de gauche (Prix) : Tracez le prix (ligne). Ajoutez une zone ombrée (fill_between) représentant l'écart-type (la volatilité) autour de la moyenne mobile.
#
# Axe Y de droite (Volume) : Tracez le volume de transaction sous forme de barres, mais faites en sorte qu'elles soient transparentes et en bas du graphique pour ne pas cacher la ligne de prix.
#
# Codez en orienté objet

# %%
days = np.arange(100)
prix = np.cumsum(np.random.randn(100)) + 100  # Marche aléatoire
volatilite = np.random.uniform(2, 5, 100)     # Ecart type
volume = np.random.randint(1000, 5000, 100)   # Volume quotidien

# %% [markdown]
# ### Exercice 2 : La Heatmap "À la main" (Imshow & Annotations)
# Le concept : C'est facile avec Seaborn (sns.heatmap), mais savoir le faire en Matplotlib pur prouve que vous comprenez le système de coordonnées matricielles.
#
# Scénario : Vous avez une matrice de confusion (ou de corrélation) 5x5.
#
# Affichez cette matrice sous forme d'image colorée (imshow).
#
# Ajoutez une Colorbar sur le côté.
#
# Le défi : Ajoutez le texte de la valeur numérique au centre de chaque case. Si la case est foncée, le texte doit être blanc ; si elle est claire, le texte doit être noir (pour la lisibilité).

# %%
data = np.random.rand(5, 5) # Matrice 5x5 de valeurs entre 0 et 1
labels = ['A', 'B', 'C', 'D', 'E']

# %% [markdown]
# ### Exercice 3 : L'Architecture Asymétrique (GridSpec & Inset)
# Le concept : Les publications scientifiques demandent souvent des mises en page non standard (un gros graphique principal et des petits graphiques d'analyse sur le côté ou en dessous) ainsi qu'un "Zoom" (Inset). plt.subplots() ne suffit plus ici.
#
# Scénario : Créez une figure divisée de manière asymétrique :
#
# Zone principale (gauche) : Prend 2/3 de la largeur. Affiche un signal sinusoïdal bruité.
#
# Zone secondaire (droite) : Prend 1/3 de la largeur. Affiche l'histogramme de ce signal (tourné horizontalement).
#
# Zoom (Inset) : À l'intérieur du graphique principal, ajoutez un petit encart (inset_axes) qui zoome sur une partie spécifique de la courbe (ex: entre x=2 et x=3).

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x) + np.random.normal(0, 0.1, 1000) # Signal bruité
